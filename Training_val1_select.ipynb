# %% [markdown]
# # Dependencies

# %%
import numpy as np
import pandas as pd

from itertools import product
from sklearn.datasets import make_regression
from sklearn.utils import shuffle
from xgboost import XGBRegressor
from xgboost import plot_importance

import matplotlib.pyplot as plt
from IPython.display import display

import time
import sys
import gc
import pickle

# %% [markdown]
# # Load Data

# %%
data = pd.read_pickle('data_all_fix_last_sale.pkl')
data = data[['date_block_num',
             'shop_id', 'item_id',
             'item_cnt_month',
             'city_code',
             'item_category_id',
             'type_code',
             'subtype_code',
             'item_cnt_month_lag_1',
             'item_cnt_month_lag_2',
             'item_cnt_month_lag_3',
             'item_cnt_month_lag_4',
             'item_cnt_month_lag_5',
             'item_cnt_month_lag_6',
             'date_avg_item_cnt_lag_1',
             'date_avg_item_cnt_lag_2',
             'date_avg_item_cnt_lag_3',
             'date_avg_item_cnt_lag_4',
             'date_avg_item_cnt_lag_5',
             'date_avg_item_cnt_lag_6',
             'date_item_avg_item_cnt_lag_1',
             'date_item_avg_item_cnt_lag_2',
             'date_item_avg_item_cnt_lag_3',
             'date_item_avg_item_cnt_lag_4',
             #'date_item_avg_item_cnt_lag_5',
             #'date_item_avg_item_cnt_lag_6',
             'date_shop_avg_item_cnt_lag_1',
             'date_shop_avg_item_cnt_lag_2',
             'date_shop_avg_item_cnt_lag_3',
             'date_shop_avg_item_cnt_lag_4',
             'date_shop_avg_item_cnt_lag_5',
             'date_shop_avg_item_cnt_lag_6',
             'date_cat_avg_item_cnt_lag_1',
             'date_cat_avg_item_cnt_lag_2',
             'date_cat_avg_item_cnt_lag_3',
             'date_cat_avg_item_cnt_lag_4',
             'date_cat_avg_item_cnt_lag_5',
             #'date_cat_avg_item_cnt_lag_6',
             'date_shop_cat_avg_item_cnt_lag_1',
             'date_shop_cat_avg_item_cnt_lag_2',
             'date_shop_cat_avg_item_cnt_lag_3',
             'date_shop_cat_avg_item_cnt_lag_4',
             'date_shop_cat_avg_item_cnt_lag_5',
             'date_shop_cat_avg_item_cnt_lag_6',
             'date_shop_type_avg_item_cnt_lag_1',
             'date_shop_type_avg_item_cnt_lag_2',
             'date_shop_type_avg_item_cnt_lag_3',
             'date_shop_type_avg_item_cnt_lag_4',
             'date_shop_type_avg_item_cnt_lag_5',
             #'date_shop_type_avg_item_cnt_lag_6',
             'date_shop_subtype_avg_item_cnt_lag_1',
             'date_shop_subtype_avg_item_cnt_lag_2',
             'date_shop_subtype_avg_item_cnt_lag_3',
             #'date_shop_subtype_avg_item_cnt_lag_4',
             #'date_shop_subtype_avg_item_cnt_lag_5',
             #'date_shop_subtype_avg_item_cnt_lag_6',
             'date_city_avg_item_cnt_lag_1',
             'date_city_avg_item_cnt_lag_2',
             #'date_city_avg_item_cnt_lag_3',
             #'date_city_avg_item_cnt_lag_4',
             #'date_city_avg_item_cnt_lag_5',
             #'date_city_avg_item_cnt_lag_6',
             'date_item_city_avg_item_cnt_lag_1',
             'date_item_city_avg_item_cnt_lag_2',
             'date_item_city_avg_item_cnt_lag_3',
             #'date_item_city_avg_item_cnt_lag_4',
             #'date_item_city_avg_item_cnt_lag_5',
             #'date_item_city_avg_item_cnt_lag_6',
             'date_type_avg_item_cnt_lag_1',
             'date_type_avg_item_cnt_lag_2',
             'date_type_avg_item_cnt_lag_3',
             'date_type_avg_item_cnt_lag_4',
             'date_type_avg_item_cnt_lag_5',
             'date_type_avg_item_cnt_lag_6',
             'date_subtype_avg_item_cnt_lag_1',
             'date_subtype_avg_item_cnt_lag_2',
             'date_subtype_avg_item_cnt_lag_3',
             'date_subtype_avg_item_cnt_lag_4',
             #'date_subtype_avg_item_cnt_lag_5',
             #'date_subtype_avg_item_cnt_lag_6',
             'delta_price_lag_1',
             'delta_price_lag_2',
             'delta_price_lag_3',
             'delta_price_lag_4',
             'delta_price_lag_5',
             'delta_price_lag_6',
             'delta_delta_price_lag_1',
             'delta_delta_price_lag_2',
             'delta_delta_price_lag_3',
             'delta_delta_price_lag_4',
             'delta_delta_price_lag_5',
             'delta_revenue_lag_1',
             'delta_revenue_lag_2',
             'delta_revenue_lag_3',
             'delta_revenue_lag_4',
             'delta_revenue_lag_5',
             'delta_revenue_lag_6',
             'month', 'days',
             'item_shop_last_sale',
             'item_last_sale',
             'item_shop_first_sale',
             'item_first_sale']]

# %%
X_train = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_train = data[data.date_block_num < 33]['item_cnt_month']
X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']
X_test = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)
del data
gc.collect();

# %% [markdown]
# # XGBoost Training

# %%
model = XGBRegressor(
    max_depth=8,
    n_estimators=5000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42,
    n_jobs=16)

model.fit(
    X_train, 
    Y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
    verbose=True, 
    early_stopping_rounds=25)
# Out:
# /home/ycxiao/DSAI/midterm_project/kaggle/lib/python3.5/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/ycxiao/DSAI/midterm_project/kaggle/lib/python3.5/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [0]	validation_0-rmse:1.18533	validation_1-rmse:1.11615
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 25 rounds.
# [1]	validation_0-rmse:1.1377	validation_1-rmse:1.07946
# [2]	validation_0-rmse:1.09711	validation_1-rmse:1.04949
# [3]	validation_0-rmse:1.06223	validation_1-rmse:1.02494
# [4]	validation_0-rmse:1.03463	validation_1-rmse:1.00488
# [5]	validation_0-rmse:1.00946	validation_1-rmse:0.987009
# [6]	validation_0-rmse:0.988102	validation_1-rmse:0.972926
# [7]	validation_0-rmse:0.971421	validation_1-rmse:0.96202
# [8]	validation_0-rmse:0.955621	validation_1-rmse:0.952527
# [9]	validation_0-rmse:0.943471	validation_1-rmse:0.945058
# [10]	validation_0-rmse:0.931638	validation_1-rmse:0.938455
# [11]	validation_0-rmse:0.922921	validation_1-rmse:0.93383
# [12]	validation_0-rmse:0.914577	validation_1-rmse:0.92974
# [13]	validation_0-rmse:0.906452	validation_1-rmse:0.925481
# [14]	validation_0-rmse:0.900177	validation_1-rmse:0.922776
# [15]	validation_0-rmse:0.895139	validation_1-rmse:0.921183
# [16]	validation_0-rmse:0.890632	validation_1-rmse:0.919564
# [17]	validation_0-rmse:0.886236	validation_1-rmse:0.917637
# [18]	validation_0-rmse:0.882168	validation_1-rmse:0.916767
# [19]	validation_0-rmse:0.878704	validation_1-rmse:0.915964
# [20]	validation_0-rmse:0.874989	validation_1-rmse:0.916693
# [21]	validation_0-rmse:0.872791	validation_1-rmse:0.916254
# [22]	validation_0-rmse:0.870356	validation_1-rmse:0.915737
# [23]	validation_0-rmse:0.868247	validation_1-rmse:0.914878
# [24]	validation_0-rmse:0.866151	validation_1-rmse:0.914162
# [25]	validation_0-rmse:0.864095	validation_1-rmse:0.914135
# [26]	validation_0-rmse:0.862469	validation_1-rmse:0.914164
# [27]	validation_0-rmse:0.860714	validation_1-rmse:0.914476
# [28]	validation_0-rmse:0.859565	validation_1-rmse:0.91366
# [29]	validation_0-rmse:0.857851	validation_1-rmse:0.912389
# [30]	validation_0-rmse:0.855931	validation_1-rmse:0.911134
# [31]	validation_0-rmse:0.854631	validation_1-rmse:0.911188
# [32]	validation_0-rmse:0.853578	validation_1-rmse:0.911489
# [33]	validation_0-rmse:0.852591	validation_1-rmse:0.911524
# [34]	validation_0-rmse:0.851845	validation_1-rmse:0.911225
# [35]	validation_0-rmse:0.850979	validation_1-rmse:0.911045
# [36]	validation_0-rmse:0.850112	validation_1-rmse:0.911082
# [37]	validation_0-rmse:0.848982	validation_1-rmse:0.910838
# [38]	validation_0-rmse:0.848272	validation_1-rmse:0.911088
# [39]	validation_0-rmse:0.847336	validation_1-rmse:0.911171
# [40]	validation_0-rmse:0.846362	validation_1-rmse:0.910944
# [41]	validation_0-rmse:0.845579	validation_1-rmse:0.911095
# [42]	validation_0-rmse:0.845047	validation_1-rmse:0.911247
# [43]	validation_0-rmse:0.844158	validation_1-rmse:0.911279
# [44]	validation_0-rmse:0.843688	validation_1-rmse:0.911093
# [45]	validation_0-rmse:0.843056	validation_1-rmse:0.910648
# [46]	validation_0-rmse:0.84253	validation_1-rmse:0.910484
# [47]	validation_0-rmse:0.841908	validation_1-rmse:0.910349
# [48]	validation_0-rmse:0.841419	validation_1-rmse:0.910503
# [49]	validation_0-rmse:0.840913	validation_1-rmse:0.910327
# [50]	validation_0-rmse:0.840409	validation_1-rmse:0.910438
# [51]	validation_0-rmse:0.839995	validation_1-rmse:0.91044
# [52]	validation_0-rmse:0.839589	validation_1-rmse:0.910124
# [53]	validation_0-rmse:0.83909	validation_1-rmse:0.909923
# [54]	validation_0-rmse:0.83875	validation_1-rmse:0.909741
# [55]	validation_0-rmse:0.838289	validation_1-rmse:0.909708
# [56]	validation_0-rmse:0.837796	validation_1-rmse:0.909661
# [57]	validation_0-rmse:0.837377	validation_1-rmse:0.909367
# [58]	validation_0-rmse:0.837058	validation_1-rmse:0.909382
# [59]	validation_0-rmse:0.836397	validation_1-rmse:0.908603
# [60]	validation_0-rmse:0.8362	validation_1-rmse:0.908427
# [61]	validation_0-rmse:0.835879	validation_1-rmse:0.908432
# [62]	validation_0-rmse:0.835342	validation_1-rmse:0.908497
# [63]	validation_0-rmse:0.83488	validation_1-rmse:0.908523
# [64]	validation_0-rmse:0.834656	validation_1-rmse:0.908763
# [65]	validation_0-rmse:0.83401	validation_1-rmse:0.907347
# [66]	validation_0-rmse:0.833748	validation_1-rmse:0.907237
# [67]	validation_0-rmse:0.833237	validation_1-rmse:0.906769
# [68]	validation_0-rmse:0.832906	validation_1-rmse:0.906725
# [69]	validation_0-rmse:0.832651	validation_1-rmse:0.906695
# [70]	validation_0-rmse:0.832202	validation_1-rmse:0.906314
# [71]	validation_0-rmse:0.831996	validation_1-rmse:0.906243
# [72]	validation_0-rmse:0.831416	validation_1-rmse:0.905587
# [73]	validation_0-rmse:0.830972	validation_1-rmse:0.904488
# [74]	validation_0-rmse:0.830539	validation_1-rmse:0.904367
# [75]	validation_0-rmse:0.829798	validation_1-rmse:0.904732
# [76]	validation_0-rmse:0.829388	validation_1-rmse:0.904581
# [77]	validation_0-rmse:0.829156	validation_1-rmse:0.905135
# [78]	validation_0-rmse:0.828909	validation_1-rmse:0.905192
# [79]	validation_0-rmse:0.828621	validation_1-rmse:0.905502
# [80]	validation_0-rmse:0.828431	validation_1-rmse:0.905442
# [81]	validation_0-rmse:0.827998	validation_1-rmse:0.904509
# [82]	validation_0-rmse:0.827761	validation_1-rmse:0.904589
# [83]	validation_0-rmse:0.827516	validation_1-rmse:0.904444
# [84]	validation_0-rmse:0.827266	validation_1-rmse:0.904286
# [85]	validation_0-rmse:0.826867	validation_1-rmse:0.904044
# [86]	validation_0-rmse:0.826616	validation_1-rmse:0.90395
# [87]	validation_0-rmse:0.826424	validation_1-rmse:0.904109
# [88]	validation_0-rmse:0.826188	validation_1-rmse:0.904184
# [89]	validation_0-rmse:0.825387	validation_1-rmse:0.902908
# [90]	validation_0-rmse:0.825212	validation_1-rmse:0.902843
# [91]	validation_0-rmse:0.825075	validation_1-rmse:0.902958
# [92]	validation_0-rmse:0.824872	validation_1-rmse:0.903015
# [93]	validation_0-rmse:0.824689	validation_1-rmse:0.902921
# [94]	validation_0-rmse:0.824449	validation_1-rmse:0.903427
# [95]	validation_0-rmse:0.824161	validation_1-rmse:0.903417
# [96]	validation_0-rmse:0.823894	validation_1-rmse:0.903739
# [97]	validation_0-rmse:0.823572	validation_1-rmse:0.903532
# [98]	validation_0-rmse:0.823341	validation_1-rmse:0.903527
# [99]	validation_0-rmse:0.823158	validation_1-rmse:0.903682
# [100]	validation_0-rmse:0.822915	validation_1-rmse:0.90351
# [101]	validation_0-rmse:0.822522	validation_1-rmse:0.903473
# [102]	validation_0-rmse:0.821988	validation_1-rmse:0.903613
# [103]	validation_0-rmse:0.821712	validation_1-rmse:0.903165
# [104]	validation_0-rmse:0.821333	validation_1-rmse:0.902935
# [105]	validation_0-rmse:0.821079	validation_1-rmse:0.902861
# [106]	validation_0-rmse:0.820674	validation_1-rmse:0.902174
# [107]	validation_0-rmse:0.820478	validation_1-rmse:0.902147
# [108]	validation_0-rmse:0.820265	validation_1-rmse:0.901854
# [109]	validation_0-rmse:0.819978	validation_1-rmse:0.901781
# [110]	validation_0-rmse:0.819877	validation_1-rmse:0.90181
# [111]	validation_0-rmse:0.819774	validation_1-rmse:0.901705
# [112]	validation_0-rmse:0.819472	validation_1-rmse:0.901484
# [113]	validation_0-rmse:0.819386	validation_1-rmse:0.901415
# [114]	validation_0-rmse:0.818983	validation_1-rmse:0.901009
# [115]	validation_0-rmse:0.818532	validation_1-rmse:0.900128
# [116]	validation_0-rmse:0.818477	validation_1-rmse:0.900065
# [117]	validation_0-rmse:0.818111	validation_1-rmse:0.899983
# [118]	validation_0-rmse:0.81796	validation_1-rmse:0.899853
# [119]	validation_0-rmse:0.817694	validation_1-rmse:0.900012
# [120]	validation_0-rmse:0.817526	validation_1-rmse:0.900054
# [121]	validation_0-rmse:0.817394	validation_1-rmse:0.899975
# [122]	validation_0-rmse:0.817107	validation_1-rmse:0.899857
# [123]	validation_0-rmse:0.81688	validation_1-rmse:0.899861
# [124]	validation_0-rmse:0.816649	validation_1-rmse:0.899821
# [125]	validation_0-rmse:0.816569	validation_1-rmse:0.899765
# [126]	validation_0-rmse:0.816426	validation_1-rmse:0.899705
# [127]	validation_0-rmse:0.816088	validation_1-rmse:0.899591
# [128]	validation_0-rmse:0.815991	validation_1-rmse:0.899537
# [129]	validation_0-rmse:0.815956	validation_1-rmse:0.899642
# [130]	validation_0-rmse:0.815887	validation_1-rmse:0.899634
# [131]	validation_0-rmse:0.815721	validation_1-rmse:0.899731
# [132]	validation_0-rmse:0.815504	validation_1-rmse:0.899664
# [133]	validation_0-rmse:0.815401	validation_1-rmse:0.899791
# [134]	validation_0-rmse:0.815228	validation_1-rmse:0.899561
# [135]	validation_0-rmse:0.814894	validation_1-rmse:0.89938
# [136]	validation_0-rmse:0.81473	validation_1-rmse:0.899546
# [137]	validation_0-rmse:0.814513	validation_1-rmse:0.899501
# [138]	validation_0-rmse:0.814174	validation_1-rmse:0.899491
# [139]	validation_0-rmse:0.81405	validation_1-rmse:0.899497
# [140]	validation_0-rmse:0.813882	validation_1-rmse:0.899524
# [141]	validation_0-rmse:0.813681	validation_1-rmse:0.899382
# [142]	validation_0-rmse:0.813501	validation_1-rmse:0.899402
# [143]	validation_0-rmse:0.813322	validation_1-rmse:0.899298
# [144]	validation_0-rmse:0.813169	validation_1-rmse:0.899386
# [145]	validation_0-rmse:0.812965	validation_1-rmse:0.899375
# [146]	validation_0-rmse:0.812832	validation_1-rmse:0.899338
# [147]	validation_0-rmse:0.812552	validation_1-rmse:0.899366
# [148]	validation_0-rmse:0.812387	validation_1-rmse:0.899396
# [149]	validation_0-rmse:0.812232	validation_1-rmse:0.899475
# [150]	validation_0-rmse:0.812066	validation_1-rmse:0.89946
# [151]	validation_0-rmse:0.811941	validation_1-rmse:0.899491
# [152]	validation_0-rmse:0.811856	validation_1-rmse:0.899502
# [153]	validation_0-rmse:0.811643	validation_1-rmse:0.898949
# [154]	validation_0-rmse:0.811566	validation_1-rmse:0.898931
# [155]	validation_0-rmse:0.811441	validation_1-rmse:0.898904
# [156]	validation_0-rmse:0.811258	validation_1-rmse:0.898764
# [157]	validation_0-rmse:0.810809	validation_1-rmse:0.898714
# [158]	validation_0-rmse:0.810777	validation_1-rmse:0.89889
# [159]	validation_0-rmse:0.810597	validation_1-rmse:0.898982
# [160]	validation_0-rmse:0.810435	validation_1-rmse:0.898884
# [161]	validation_0-rmse:0.810294	validation_1-rmse:0.898765
# [162]	validation_0-rmse:0.81017	validation_1-rmse:0.89879
# [163]	validation_0-rmse:0.810046	validation_1-rmse:0.898982
# [164]	validation_0-rmse:0.809885	validation_1-rmse:0.899358
# [165]	validation_0-rmse:0.809786	validation_1-rmse:0.899309
# [166]	validation_0-rmse:0.809684	validation_1-rmse:0.899245
# [167]	validation_0-rmse:0.8096	validation_1-rmse:0.899307
# [168]	validation_0-rmse:0.809273	validation_1-rmse:0.899228
# [169]	validation_0-rmse:0.809005	validation_1-rmse:0.899094
# [170]	validation_0-rmse:0.808818	validation_1-rmse:0.899394
# [171]	validation_0-rmse:0.808754	validation_1-rmse:0.899358
# [172]	validation_0-rmse:0.808671	validation_1-rmse:0.89931
# [173]	validation_0-rmse:0.808604	validation_1-rmse:0.899218
# [174]	validation_0-rmse:0.808441	validation_1-rmse:0.899183
# [175]	validation_0-rmse:0.80836	validation_1-rmse:0.899174
# [176]	validation_0-rmse:0.808065	validation_1-rmse:0.89883
# [177]	validation_0-rmse:0.807527	validation_1-rmse:0.898514
# [178]	validation_0-rmse:0.807443	validation_1-rmse:0.898581
# [179]	validation_0-rmse:0.807385	validation_1-rmse:0.898563
# [180]	validation_0-rmse:0.807314	validation_1-rmse:0.898517
# [181]	validation_0-rmse:0.807206	validation_1-rmse:0.898484
# [182]	validation_0-rmse:0.807124	validation_1-rmse:0.89871
# [183]	validation_0-rmse:0.80707	validation_1-rmse:0.89871
# [184]	validation_0-rmse:0.806951	validation_1-rmse:0.898597
# [185]	validation_0-rmse:0.806745	validation_1-rmse:0.898442
# [186]	validation_0-rmse:0.806678	validation_1-rmse:0.898476
# [187]	validation_0-rmse:0.80661	validation_1-rmse:0.898454
# [188]	validation_0-rmse:0.806583	validation_1-rmse:0.898475
# [189]	validation_0-rmse:0.806441	validation_1-rmse:0.898281
# [190]	validation_0-rmse:0.806317	validation_1-rmse:0.898237
# [191]	validation_0-rmse:0.806214	validation_1-rmse:0.898305
# [192]	validation_0-rmse:0.806124	validation_1-rmse:0.898268
# [193]	validation_0-rmse:0.805952	validation_1-rmse:0.898425
# [194]	validation_0-rmse:0.8059	validation_1-rmse:0.898354
# [195]	validation_0-rmse:0.805517	validation_1-rmse:0.898404
# [196]	validation_0-rmse:0.805302	validation_1-rmse:0.898603
# [197]	validation_0-rmse:0.805197	validation_1-rmse:0.898572
# [198]	validation_0-rmse:0.805114	validation_1-rmse:0.898667
# [199]	validation_0-rmse:0.805028	validation_1-rmse:0.898693
# [200]	validation_0-rmse:0.804765	validation_1-rmse:0.898715
# [201]	validation_0-rmse:0.804592	validation_1-rmse:0.898703
# [202]	validation_0-rmse:0.804508	validation_1-rmse:0.898701
# [203]	validation_0-rmse:0.804464	validation_1-rmse:0.898686
# [204]	validation_0-rmse:0.803964	validation_1-rmse:0.898957
# [205]	validation_0-rmse:0.803766	validation_1-rmse:0.898952
# [206]	validation_0-rmse:0.803676	validation_1-rmse:0.898911
# [207]	validation_0-rmse:0.80358	validation_1-rmse:0.898901
# [208]	validation_0-rmse:0.803456	validation_1-rmse:0.898983
# [209]	validation_0-rmse:0.803294	validation_1-rmse:0.899064
# [210]	validation_0-rmse:0.803206	validation_1-rmse:0.899048
# [211]	validation_0-rmse:0.803019	validation_1-rmse:0.899009
# [212]	validation_0-rmse:0.802882	validation_1-rmse:0.899063
# [213]	validation_0-rmse:0.802108	validation_1-rmse:0.899417
# [214]	validation_0-rmse:0.801893	validation_1-rmse:0.899214
# [215]	validation_0-rmse:0.801826	validation_1-rmse:0.89912
# Stopping. Best iteration:
# [190]	validation_0-rmse:0.806317	validation_1-rmse:0.898237
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, eta=0.3, gamma=0, importance_type='gain',
#        learning_rate=0.1, max_delta_step=0, max_depth=8,
#        min_child_weight=300, missing=None, n_estimators=5000, n_jobs=16,
#        nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=42, silent=True,
#        subsample=0.8)

# %%
def plot_features(booster, figsize):
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)
plot_features(model, (10,25))

# %% [markdown]
# # Output File

# %%
Y_pred = model.predict(X_valid).clip(0, 20)
Y_test = model.predict(X_test).clip(0, 20)

test  = pd.read_csv('./input/test.csv').set_index('ID')
submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})
submission.to_csv('submission_val1_select_es25.csv', index=False)
